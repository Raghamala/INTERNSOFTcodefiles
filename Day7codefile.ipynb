# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghamala/INTERNSOFTcodefiles/blob/main/Day7codefile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
pandas.__version__
# Out:
# '1.5.3'

# %%
import numpy as np
import pandas as pd

# %%
counts=pd.Series([234,532,545,178])
counts
# Out:
# 0    234
# 1    532
# 2    545
# 3    178
# dtype: int64

# %%
counts.values
# Out:
# array([234, 532, 545, 178])

# %%
counts.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
bacteria=pd.Series([234,563,756,892],
                   index=['Firmicutes','Proteobacteria','Actionbacteria','Bacteroidetes'])
bacteria
# Out:
# Firmicutes        234
# Proteobacteria    563
# Actionbacteria    756
# Bacteroidetes     892
# dtype: int64

# %%
bacteria['Actionbacteria']
# Out:
# 756

# %%
bacteria[1]
# Out:
# 563

# %%
bacteria.name='counts'
bacteria.index.name='phylum'
bacteria
# Out:
# phylum
# Firmicutes        234
# Proteobacteria    563
# Actionbacteria    756
# Bacteroidetes     892
# Name: counts, dtype: int64

# %%
np.log(bacteria)
# Out:
# phylum
# Firmicutes        5.455321
# Proteobacteria    6.333280
# Actionbacteria    6.628041
# Bacteroidetes     6.793466
# Name: counts, dtype: float64

# %%
bacteria[bacteria>800]
# Out:
# phylum
# Bacteroidetes    892
# Name: counts, dtype: int64

# %%
bacteria_dict={'Firmicutes':234,'Proteobacteria':563,'Actionbacteria':756,'Bacteroidetes':892}
print(bacteria_dict)
pd.Series(bacteria_dict)
# Out:
# {'Firmicutes': 234, 'Proteobacteria': 563, 'Actionbacteria': 756, 'Bacteroidetes': 892}
# Firmicutes        234
# Proteobacteria    563
# Actionbacteria    756
# Bacteroidetes     892
# dtype: int64

# %%
data={"Province":["FL","FL","NH","NH","ZH"],
      "Year":[2010,2011,2012,2011,2014],
      "Literacy":[0.3,0.2,0.4,0.5,0.4]}
print(data)
data=pd.DataFrame(data)
data
# Out:
# {'Province': ['FL', 'FL', 'NH', 'NH', 'ZH'], 'Year': [2010, 2011, 2012, 2011, 2014], 'Literacy': [0.3, 0.2, 0.4, 0.5, 0.4]}
#   Province  Year  Literacy
# 0       FL  2010       0.3
# 1       FL  2011       0.2
# 2       NH  2012       0.4
# 3       NH  2011       0.5
# 4       ZH  2014       0.4

# %%
df=pd.DataFrame(data,columns=["Year","Province","Literacy"])
df
# Out:
#    Year Province  Literacy
# 0  2010       FL       0.3
# 1  2011       FL       0.2
# 2  2012       NH       0.4
# 3  2011       NH       0.5
# 4  2014       ZH       0.4

# %%
df['nonsense']=df.Year/df.Literacy
df
# Out:
#    Year Province  Literacy  nonsense
# 0  2010       FL       0.3    6700.0
# 1  2011       FL       0.2   10055.0
# 2  2012       NH       0.4    5030.0
# 3  2011       NH       0.5    4022.0
# 4  2014       ZH       0.4    5035.0

# %%
df['Serie_aligned']=pd.Series(range(5),index=[0,1,2,3,4])
df
# Out:
#    Year Province  Literacy  nonsense  Serie_aligned
# 0  2010       FL       0.3    6700.0              0
# 1  2011       FL       0.2   10055.0              1
# 2  2012       NH       0.4    5030.0              2
# 3  2011       NH       0.5    4022.0              3
# 4  2014       ZH       0.4    5035.0              4

# %%
df.to_dict()
# Out:
# {'Year': {0: 2010, 1: 2011, 2: 2012, 3: 2011, 4: 2014},
#  'Province': {0: 'FL', 1: 'FL', 2: 'NH', 3: 'NH', 4: 'ZH'},
#  'Literacy': {0: 0.3, 1: 0.2, 2: 0.4, 3: 0.5, 4: 0.4},
#  'nonsense': {0: 6700.0, 1: 10055.0, 2: 5030.0, 3: 4022.0, 4: 5035.0},
#  'Serie_aligned': {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}}

# %%
pd.DataFrame(df.to_dict())
# Out:
#    Year Province  Literacy  nonsense  Serie_aligned
# 0  2010       FL       0.3    6700.0              0
# 1  2011       FL       0.2   10055.0              1
# 2  2012       NH       0.4    5030.0              2
# 3  2011       NH       0.5    4022.0              3
# 4  2014       ZH       0.4    5035.0              4

# %%
data=[{'a':i,'b':10*i}for i in range(6)]
print(data)
pd.DataFrame(data)
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 10}, {'a': 2, 'b': 20}, {'a': 3, 'b': 30}, {'a': 4, 'b': 40}, {'a': 5, 'b': 50}]
#    a   b
# 0  0   0
# 1  1  10
# 2  2  20
# 3  3  30
# 4  4  40
# 5  5  50

# %%
pd.DataFrame([{'aa':1,'bb':2},{'bb':3,'cc':6}])
# Out:
#     aa  bb   cc
# 0  1.0   2  NaN
# 1  NaN   3  6.0

# %%
pd.DataFrame(np.random.randint(2,12),
             columns=['foo','bar'],
             index=['a','b','c'])
# Out:
#    foo  bar
# a   10   10
# b   10   10
# c   10   10

# %%
ind=pd.Index([20,30,32,45,6,7])
ind
# Out:
# Int64Index([20, 30, 32, 45, 6, 7], dtype='int64')

# %%
ind[1]
# Out:
# 30

# %%
ind[3]
# Out:
# 45

# %%
ind[::]
# Out:
# Int64Index([20, 30, 32, 45, 6, 7], dtype='int64')

# %%
print(ind.size,ind.shape,ind.ndim,ind.dtype)
# Out:
# 6 (6,) 1 int64

# %%
ind[2:3:1]
# Out:
# Int64Index([32], dtype='int64')

# %%
rng=np.random.RandomState(12)
ser=pd.Series(rng.randint(0,10,4))
ser
# Out:
# 0    6
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
dfr=pd.DataFrame(rng.randint(0,10,(8,4)),
                 columns=['A','B','C','D'])
dfr
# Out:
#    A  B  C  D
# 0  5  7  3  8
# 1  5  3  1  0
# 2  8  7  5  8
# 3  1  2  8  3
# 4  1  3  7  2
# 5  7  2  0  0
# 6  7  6  4  4
# 7  3  7  5  6

# %%
np.exp(ser)
# Out:
# 0    2980.957987
# 1     148.413159
# 2     148.413159
# 3    1096.633158
# dtype: float64

# %%
np.sin(dfr*np.pi/8)
# Out:
#               A         B             C             D
# 0  9.238795e-01  0.382683  9.238795e-01  1.224647e-16
# 1  9.238795e-01  0.923880  3.826834e-01  0.000000e+00
# 2  1.224647e-16  0.382683  9.238795e-01  1.224647e-16
# 3  3.826834e-01  0.707107  1.224647e-16  9.238795e-01
# 4  3.826834e-01  0.923880  3.826834e-01  7.071068e-01
# 5  3.826834e-01  0.707107  0.000000e+00  0.000000e+00
# 6  3.826834e-01  0.707107  1.000000e+00  1.000000e+00
# 7  9.238795e-01  0.382683  9.238795e-01  7.071068e-01

# %%
area=pd.Series({'alaska':1234443,'texas':4522453,
                'california':347785},name='area')
population=pd.Series({'california':277532,'texas':998755,
                      'new york':655432},name='population')
print(area)
population
# Out:
# alaska        1234443
# texas         4522453
# california     347785
# Name: area, dtype: int64
# california    277532
# texas         998755
# new york      655432
# Name: population, dtype: int64

# %%
population/area
# Out:
# alaska             NaN
# california    0.797999
# new york           NaN
# texas         0.220844
# dtype: float64

# %%
area.index|population.index
# Out:
# <ipython-input-47-b132a20899a3>:1: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead.
#   area.index|population.index
# Index(['alaska', 'california', 'new york', 'texas'], dtype='object')

# %%
A=pd.Series([2,3,4],index=[0,1,2])
B=pd.Series([1.,3,4],index=[1,2,3])
print(A)
print(B)
B
A+B
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64
# 1    1.0
# 2    3.0
# 3    4.0
# dtype: float64
# 0    NaN
# 1    4.0
# 2    7.0
# 3    NaN
# dtype: float64

# %%
A.add(B,fill_value=0)
# Out:
# 0    2.0
# 1    4.0
# 2    7.0
# 3    4.0
# dtype: float64

# %%
df
# Out:
#    Year Province  Literacy  nonsense  Serie_aligned
# 0  2010       FL       0.3    6700.0              0
# 1  2011       FL       0.2   10055.0              1
# 2  2012       NH       0.4    5030.0              2
# 3  2011       NH       0.5    4022.0              3
# 4  2014       ZH       0.4    5035.0              4

# %%
df2=pd.DataFrame({"Province":["FL","NH","ZH"],"Population":["10000","20000","30000"]})
df2
# Out:
#   Province Population
# 0       FL      10000
# 1       NH      20000
# 2       ZH      30000

# %%
df.merge(df2)
# Out:
#    Year Province  Literacy  nonsense  Serie_aligned Population
# 0  2010       FL       0.3    6700.0              0      10000
# 1  2011       FL       0.2   10055.0              1      10000
# 2  2012       NH       0.4    5030.0              2      20000
# 3  2011       NH       0.5    4022.0              3      20000
# 4  2014       ZH       0.4    5035.0              4      30000

# %%
df3=pd.DataFrame({"Province":["FL","NH"],"Population":["10000","20000"]})
df3
df.merge(df3,right_on='Province',left_on='Province')
# Out:
#    Year Province  Literacy  nonsense  Serie_aligned Population
# 0  2010       FL       0.3    6700.0              0      10000
# 1  2011       FL       0.2   10055.0              1      10000
# 2  2012       NH       0.4    5030.0              2      20000
# 3  2011       NH       0.5    4022.0              3      20000

# %%
df4=pd.DataFrame({"Province":["FL","NH","UT"],"Population":["10000","20000","40000"]})
df.merge(df4,how='outer')
# Out:
#      Year Province  Literacy  nonsense  Serie_aligned Population
# 0  2010.0       FL       0.3    6700.0            0.0      10000
# 1  2011.0       FL       0.2   10055.0            1.0      10000
# 2  2012.0       NH       0.4    5030.0            2.0      20000
# 3  2011.0       NH       0.5    4022.0            3.0      20000
# 4  2014.0       ZH       0.4    5035.0            4.0        NaN
# 5     NaN       UT       NaN       NaN            NaN      40000

# %%
df5=pd.DataFrame({"Province":["FL","NH","FL"],"Population":["10000","20000","300000"]})
print(df)
df.merge(df5,how='outer')
# Out:
#    Year Province  Literacy  nonsense  Serie_aligned
# 0  2010       FL       0.3    6700.0              0
# 1  2011       FL       0.2   10055.0              1
# 2  2012       NH       0.4    5030.0              2
# 3  2011       NH       0.5    4022.0              3
# 4  2014       ZH       0.4    5035.0              4
#    Year Province  Literacy  nonsense  Serie_aligned Population
# 0  2010       FL       0.3    6700.0              0      10000
# 1  2010       FL       0.3    6700.0              0     300000
# 2  2011       FL       0.2   10055.0              1      10000
# 3  2011       FL       0.2   10055.0              1     300000
# 4  2012       NH       0.4    5030.0              2      20000
# 5  2011       NH       0.5    4022.0              3      20000
# 6  2014       ZH       0.4    5035.0              4        NaN

# %%
serie_a=pd.Series([np.nan,2.5,np.nan,3.5,4.5,np.nan],
                  index=['f','e','d','c','b','a'])
serie_b=pd.Series(np.arange(len(serie_a),dtype=np.float64),
                  index=['f','e','d','c','b','a'])

# %%
serie_a
# Out:
# f    NaN
# e    2.5
# d    NaN
# c    3.5
# b    4.5
# a    NaN
# dtype: float64

# %%
serie_b
# Out:
# f    0.0
# e    1.0
# d    2.0
# c    3.0
# b    4.0
# a    5.0
# dtype: float64

# %%
pd.Series(np.where(pd.isnull(serie_a),serie_b,serie_a),index=serie_a.index)
# Out:
# f    0.0
# e    2.5
# d    2.0
# c    3.5
# b    4.5
# a    5.0
# dtype: float64

# %%
serie_a.combine_first(serie_b)
# Out:
# f    0.0
# e    2.5
# d    2.0
# c    3.5
# b    4.5
# a    5.0
# dtype: float64
